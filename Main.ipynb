# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import spacy
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.base import TransformerMixin
from sklearn.svm import LinearSVC
from sklearn.pipeline import Pipeline
from spacy.lang.en.stop_words import STOP_WORDS
from collections import Counter
from sklearn.preprocessing import MultiLabelBinarizer

# %%
df = pd.read_csv('data.csv')
nlp = spacy.load("en_core_web_sm")

df_pos = df[df.Sentiment == 'positive']

df_neu = df[df.Sentiment == 'neutral']

df_neg = df[df.Sentiment == 'negative']

# %%
df_pos["pos"] = df_pos.Sentence.apply(lambda text: " "
        .join(token.lemma_ for token in nlp(text) if
              not token.is_punct
              and not token.is_stop))
              
pos_words = df_pos["pos"]
pos_words = pos_words.to_string()
vectorizer = CountVectorizer()
matrix = vectorizer.fit_transform([pos_words])

counts_df = pd.DataFrame(matrix.toarray(), columns=vectorizer.get_feature_names())
counts_df.T.sort_values(by=0, ascending=False).head(20)

# %%
df_neu["neu"] = df_neu.Sentence.apply(lambda text: " "
        .join(token.lemma_ for token in nlp(text) if
              not token.is_punct
              and not token.is_stop))
neu_words = df_neu["neu"]
neu_words = neu_words.to_string()
vectorizer = CountVectorizer()
matrix = vectorizer.fit_transform([neu_words])

counts_df = pd.DataFrame(matrix.toarray(), columns=vectorizer.get_feature_names())
counts_df.T.sort_values(by=0, ascending=False).head(20)

# %%
df_neg["neg"] = df_neg.Sentence.apply(lambda text: " "
        .join(token.lemma_ for token in nlp(text) if
              not token.is_punct
              and not token.is_stop))
              
neg_words = df_neg["neg"]
neg_words = neg_words.to_string()
vectorizer = CountVectorizer()
matrix = vectorizer.fit_transform([neg_words])

counts_df = pd.DataFrame(matrix.toarray(), columns=vectorizer.get_feature_names())
counts_df.T.sort_values(by=0, ascending=False).head(20)
